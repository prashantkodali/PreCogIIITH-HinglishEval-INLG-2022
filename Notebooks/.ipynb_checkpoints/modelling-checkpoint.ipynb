# %%
import os, sys, re, pickle
from tqdm import tqdm
import os.path as osp

import pandas as pd
import numpy as np
from collections import Counter


from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.impute import SimpleImputer

from statistics import mean

import statsmodels.api as sm
from sklearn.neural_network import MLPRegressor

from xgboost import XGBClassifier

# %%
traindf_path = "../dataset/traindf.json"
valdf_path = "../dataset/valdf.json"
testdf_file_path = "../dataset/testdf.json"

# %%
traindf = pd.read_json(traindf_path)
valdf = pd.read_json(valdf_path)
testdf = pd.read_json(testdf_file_path)

# %%
traindf.columns, traindf.shape
# Out:
# (Index(['index', 'English', 'Hindi', 'Hinglish', 'Average rating',
#         'Disagreement', 'hum_gen', 'Hinglish_csnliop', 'hum_gen_csnliop',
#         'Hinglish_norm', 'Hinglish_lid', 'hum_gen_norm', 'hum_gen_lid',
#         'Hinglish_pos', 'hum_gen_pos', 'Hinglish_cmi_scores',
#         'Hinglish_burstiness_scores', 'Hinglish_sp_scores', 'symcom_scores_pos',
#         'symcom_scores_sent', 'NOUN_symcom', 'AUX_symcom', 'CCONJ_symcom',
#         'ADP_symcom', 'NUM_symcom', 'PRON_symcom', 'PART_symcom', 'VERB_symcom',
#         'PROPN_symcom', 'SCONJ_symcom', 'ADV_symcom', 'INTJ_symcom',
#         'DET_symcom', 'ADJ_symcom', 'symcom_+1_count', 'symcom_-1_count',
#         'symcom_na_count', 'symcom_others', 'Hinglish_length',
#         'Hingilish_xlmr_scores', 'hum_gen_tokens', 'hum_gen_xlmr_scores',
#         'xlm_r_ppl_scores_delta', 'eucl', 'cityblock', 'cosine'],
#        dtype='object'),
#  (2766, 46))

# %%
valdf.columns, valdf.shape
# Out:
# (Index(['index', 'English', 'Hindi', 'Hinglish', 'hum_gen', 'Hinglish_csnliop',
#         'hum_gen_csnliop', 'Hinglish_norm', 'Hinglish_lid', 'hum_gen_norm',
#         'hum_gen_lid', 'Hinglish_pos', 'hum_gen_pos', 'Hinglish_cmi_scores',
#         'Hinglish_burstiness_scores', 'Hinglish_sp_scores', 'symcom_scores_pos',
#         'symcom_scores_sent', 'PRON_symcom', 'ADV_symcom', 'PART_symcom',
#         'DET_symcom', 'NOUN_symcom', 'ADP_symcom', 'VERB_symcom', 'AUX_symcom',
#         'ADJ_symcom', 'SCONJ_symcom', 'PROPN_symcom', 'CCONJ_symcom',
#         'NUM_symcom', 'INTJ_symcom', 'symcom_+1_count', 'symcom_-1_count',
#         'symcom_na_count', 'symcom_others', 'hum_gen_tokens',
#         'hum_gen_xlmr_scores', 'Hingilish_xlmr_scores'],
#        dtype='object'),
#  (395, 39))

# %%
valdf["Hinglish_length"] = valdf["Hinglish_norm"].apply(len)
testdf["Hinglish_length"] = testdf["Hinglish_norm"].apply(len)

# %%
xlm_r_ppl_scores_delta = []

for ind,row in tqdm(traindf.iterrows()):

    try:
        xlm_r_ppl_scores_delta.append(row["Hingilish_xlmr_scores"] - mean(row["hum_gen_xlmr_scores"]))
    except TypeError:
        xlm_r_ppl_scores_delta.append(np.nan)

        
traindf["xlm_r_ppl_scores_delta"] = xlm_r_ppl_scores_delta
# Out:
# 2766it [00:00, 10955.97it/s]

# %%
xlm_r_ppl_scores_delta = []

for ind,row in tqdm(valdf.iterrows()):

    try:
        xlm_r_ppl_scores_delta.append(row["Hingilish_xlmr_scores"] - mean(row["hum_gen_xlmr_scores"]))
    except TypeError:
        xlm_r_ppl_scores_delta.append(np.nan)

        
valdf["xlm_r_ppl_scores_delta"] = xlm_r_ppl_scores_delta
# Out:
# 395it [00:00, 9050.91it/s]

# %%
xlm_r_ppl_scores_delta = []

for ind,row in tqdm(testdf.iterrows()):

    try:
        xlm_r_ppl_scores_delta.append(row["Hingilish_xlmr_scores"] - mean(row["hum_gen_xlmr_scores"]))
    except TypeError:
        xlm_r_ppl_scores_delta.append(np.nan)

        
testdf["xlm_r_ppl_scores_delta"] = xlm_r_ppl_scores_delta
# Out:
# 791it [00:00, 10825.37it/s]

# %%
import numpy as np
import torch
import pickle as pkl
import scipy

# %%
trh = torch.load('train.human.pt', map_location=torch.device('cpu')).numpy()
trs = torch.load('train.synth.pt',map_location=torch.device('cpu')).numpy()
teh = torch.load('test.human.pt', map_location=torch.device('cpu')).numpy()
tes = torch.load('test.synth.pt',map_location=torch.device('cpu')).numpy()

# %%
from scipy.spatial.distance import euclidean, cityblock

# %%
tr_eu = []
tr_ci = []

te_eu = []
te_ci = []

for i in range(len(trh)):
    tr_eu.append(euclidean(trh[i], trs[i]))
    tr_ci.append(cityblock(trh[i], trs[i]))

for i in range(len(teh)):
    te_eu.append(euclidean(teh[i], tes[i]))
    te_ci.append(euclidean(teh[i], tes[i]))

traindf["eucl"] = tr_eu
traindf["cityblock"] = tr_ci

testdf["eucl"], testdf["cityblock"]  = te_eu, te_ci

# %%
trh = torch.load('train.human.pt', map_location=torch.device('cpu'))
trs = torch.load('train.synth.pt',map_location=torch.device('cpu'))
teh = torch.load('test.human.pt', map_location=torch.device('cpu'))
tes = torch.load('test.synth.pt',map_location=torch.device('cpu'))


cosine_train = torch.nn.CosineSimilarity(dim = 1)(trs, trh)
cosine_test = torch.nn.CosineSimilarity(dim = 1)(tes, teh)

traindf["cosine"] = cosine_train.numpy()
testdf["cosine"] = cosine_test.numpy()

# %%
len(tr_eu), len(te_eu)
# Out:
# (2766, 791)

# %%
traindf.columns
# Out:
# Index(['index', 'English', 'Hindi', 'Hinglish', 'Average rating',
#        'Disagreement', 'hum_gen', 'Hinglish_csnliop', 'hum_gen_csnliop',
#        'Hinglish_norm', 'Hinglish_lid', 'hum_gen_norm', 'hum_gen_lid',
#        'Hinglish_pos', 'hum_gen_pos', 'Hinglish_cmi_scores',
#        'Hinglish_burstiness_scores', 'Hinglish_sp_scores', 'symcom_scores_pos',
#        'symcom_scores_sent', 'NOUN_symcom', 'AUX_symcom', 'CCONJ_symcom',
#        'ADP_symcom', 'NUM_symcom', 'PRON_symcom', 'PART_symcom', 'VERB_symcom',
#        'PROPN_symcom', 'SCONJ_symcom', 'ADV_symcom', 'INTJ_symcom',
#        'DET_symcom', 'ADJ_symcom', 'symcom_+1_count', 'symcom_-1_count',
#        'symcom_na_count', 'symcom_others', 'Hinglish_length',
#        'Hingilish_xlmr_scores', 'hum_gen_tokens', 'hum_gen_xlmr_scores',
#        'xlm_r_ppl_scores_delta', 'eucl', 'cityblock', 'cosine'],
#       dtype='object')

# %% [markdown]
# # columns MinMax scaling normalisation

# %%
def standarize_cols(df, cols_to_be_standardized, newcolnames):
    
    X = df[cols_to_be_standardized]
    coldata_numpy_reshaped = X.to_numpy()
    scale = StandardScaler().fit(coldata_numpy_reshaped)        
    transformed_coldata = scale.transform(coldata_numpy_reshaped)
    df = pd.concat([df, pd.DataFrame(transformed_coldata, columns = newcolnames)], axis=1)
    return df

def normalize_cols(df, cols_to_be_normalised, newcolnames):
    
    X = df[cols_to_be_normalised]
    coldata_numpy_reshaped = X.to_numpy()
    norm = MinMaxScaler().fit(coldata_numpy_reshaped)    
    transformed_coldata = norm.transform(coldata_numpy_reshaped)
    df = pd.concat([df, pd.DataFrame(transformed_coldata, columns = newcolnames)], axis=1)
    return df, norm


def transform_normalize_cols(df, cols_to_be_normalised, newcolnames, normalizer):
    
    X = df[cols_to_be_normalised]
    coldata_numpy_reshaped = X.to_numpy()
    # norm = MinMaxScaler().fit(coldata_numpy_reshaped)    
    transformed_coldata = normalizer.transform(coldata_numpy_reshaped)
    df = pd.concat([df, pd.DataFrame(transformed_coldata, columns = newcolnames)], axis=1)
    return df

# %%
def generate_colnames_withSuffix(colnames, suffix ):
    newcolnames = []
    for col in colnames:
        newcolnames.append(col+'_'+suffix)
        
    return newcolnames

cols_to_be_standardized = ['Hinglish_cmi_scores',
                           'Hinglish_burstiness_scores',
                           'Hinglish_sp_scores', 
                           'symcom_scores_sent',
                           'NOUN_symcom',
                           'AUX_symcom',
                           'CCONJ_symcom',
                           'ADP_symcom',
                           'NUM_symcom',
                           'PRON_symcom',
                           'PART_symcom',
                           'VERB_symcom',
                           'PROPN_symcom',
                           'SCONJ_symcom', 
                           'ADV_symcom',
                           'INTJ_symcom',
                           'DET_symcom',
                           'ADJ_symcom',
                           'symcom_+1_count',
                           'symcom_-1_count',
                           'symcom_na_count', 
                           'symcom_others',
                           'xlm_r_ppl_scores_delta',
                           'Hinglish_length',
                           'eucl', 
                           'cityblock', 
                           'cosine'
                          ]

traindf_standard_all, normalizer_train = normalize_cols(
                                    df = traindf, 
                                    cols_to_be_normalised = cols_to_be_standardized,
                                    newcolnames = generate_colnames_withSuffix(cols_to_be_standardized, 
                                                                     suffix = 'standardized'))


# valdf_standard_all = transform_normalize_cols(
#                                     df = valdf, 
#                                     cols_to_be_normalised = cols_to_be_standardized,
#                                     newcolnames = generate_colnames_withSuffix(cols_to_be_standardized, 
#                                                                      suffix = 'standardized'),
#                                     normalizer = normalizer_train)


testdf_standard_all = transform_normalize_cols(
                                    df = testdf, 
                                    cols_to_be_normalised = cols_to_be_standardized,
                                    newcolnames = generate_colnames_withSuffix(cols_to_be_standardized, 
                                                                     suffix = 'standardized'),
                                    normalizer = normalizer_train)

# %%
traindf_standard_all.columns
# Out:
# Index(['index', 'English', 'Hindi', 'Hinglish', 'Average rating',
#        'Disagreement', 'hum_gen', 'Hinglish_csnliop', 'hum_gen_csnliop',
#        'Hinglish_norm', 'Hinglish_lid', 'hum_gen_norm', 'hum_gen_lid',
#        'Hinglish_pos', 'hum_gen_pos', 'Hinglish_cmi_scores',
#        'Hinglish_burstiness_scores', 'Hinglish_sp_scores', 'symcom_scores_pos',
#        'symcom_scores_sent', 'NOUN_symcom', 'AUX_symcom', 'CCONJ_symcom',
#        'ADP_symcom', 'NUM_symcom', 'PRON_symcom', 'PART_symcom', 'VERB_symcom',
#        'PROPN_symcom', 'SCONJ_symcom', 'ADV_symcom', 'INTJ_symcom',
#        'DET_symcom', 'ADJ_symcom', 'symcom_+1_count', 'symcom_-1_count',
#        'symcom_na_count', 'symcom_others', 'Hinglish_length',
#        'Hingilish_xlmr_scores', 'hum_gen_tokens', 'hum_gen_xlmr_scores',
#        'xlm_r_ppl_scores_delta', 'eucl', 'cityblock', 'cosine',
#        'Hinglish_cmi_scores_standardized',
#        'Hinglish_burstiness_scores_standardized',
#        'Hinglish_sp_scores_standardized', 'symcom_scores_sent_standardized',
#        'NOUN_symcom_standardized', 'AUX_symcom_standardized',
#        'CCONJ_symcom_standardized', 'ADP_symcom_standardized',
#        'NUM_symcom_standardized', 'PRON_symcom_standardized',
#        'PART_symcom_standardized', 'VERB_symcom_standardized',
#        'PROPN_symcom_standardized', 'SCONJ_symcom_standardized',
#        'ADV_symcom_standardized', 'INTJ_symcom_standardized',
#        'DET_symcom_standardized', 'ADJ_symcom_standardized',
#        'symcom_+1_count_standardized', 'symcom_-1_count_standardized',
#        'symcom_na_count_standardized', 'symcom_others_standardized',
#        'xlm_r_ppl_scores_delta_standardized', 'Hinglish_length_standardized',
#        'eucl_standardized', 'cityblock_standardized', 'cosine_standardized'],
#       dtype='object')

# %% [markdown]
# # Linear Regression

# %%
X = traindf_standard_all[['Hinglish_cmi_scores_standardized',
       'Hinglish_burstiness_scores_standardized',
       'Hinglish_sp_scores_standardized',
        'symcom_scores_sent_standardized',
       'NOUN_symcom_standardized', 'AUX_symcom_standardized',
       'CCONJ_symcom_standardized', 'ADP_symcom_standardized',
       'NUM_symcom_standardized', 'PRON_symcom_standardized',
       'PART_symcom_standardized', 'VERB_symcom_standardized',
       'PROPN_symcom_standardized', 'SCONJ_symcom_standardized',
       'ADV_symcom_standardized', 'INTJ_symcom_standardized',
       'DET_symcom_standardized', 'ADJ_symcom_standardized',
       'symcom_+1_count_standardized', 'symcom_-1_count_standardized',
       'symcom_na_count_standardized', 'symcom_others_standardized']]


sim = SimpleImputer(missing_values=np.nan, strategy='mean')

X_imputed_data = sim.fit_transform(X.values)

y = traindf_standard_all["Average rating"]

model = sm.OLS(y, X_imputed_data).fit()
predictions = model.predict(X) # make the predictions by the model

# Print out the statistics
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:         Average rating   R-squared:                       0.103
# Model:                            OLS   Adj. R-squared:                  0.096
# Method:                 Least Squares   F-statistic:                     14.95
# Date:                Mon, 09 May 2022   Prob (F-statistic):           6.86e-51
# Time:                        23:30:43   Log-Likelihood:                -5093.7
# No. Observations:                2766   AIC:                         1.023e+04
# Df Residuals:                    2744   BIC:                         1.036e+04
# Df Model:                          21
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# x1            -0.4323      0.207     -2.086      0.037      -0.839      -0.026
# x2            -0.6985      0.247     -2.832      0.005      -1.182      -0.215
# x3            -0.5189      0.568     -0.914      0.361      -1.632       0.594
# x4             0.0876      0.236      0.371      0.711      -0.375       0.551
# x5             0.6767      0.152      4.459      0.000       0.379       0.974
# x6            -0.3686      0.258     -1.429      0.153      -0.875       0.137
# x7             0.3801      0.200      1.898      0.058      -0.013       0.773
# x8            -0.3724      0.239     -1.561      0.119      -0.840       0.095
# x9            -0.6349      0.292     -2.177      0.030      -1.207      -0.063
# x10           -0.3965      0.218     -1.821      0.069      -0.823       0.030
# x11           -0.5467      0.346     -1.582      0.114      -1.224       0.131
# x12           -0.8484      0.162     -5.236      0.000      -1.166      -0.531
# x13            0.0864      0.182      0.475      0.635      -0.270       0.443
# x14            1.1002      0.623      1.766      0.077      -0.121       2.322
# x15            0.1240      0.186      0.666      0.506      -0.241       0.489
# x16            0.4521      0.561      0.806      0.420      -0.647       1.551
# x17           -0.5215      0.198     -2.630      0.009      -0.910      -0.133
# x18            0.4764      0.126      3.775      0.000       0.229       0.724
# x19            2.4531      0.632      3.884      0.000       1.215       3.692
# x20            6.8720      0.382     17.974      0.000       6.122       7.622
# x21            7.1801      0.346     20.736      0.000       6.501       7.859
# x22            3.4884      0.530      6.584      0.000       2.449       4.527
# ==============================================================================
# Omnibus:                      113.138   Durbin-Watson:                   1.983
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              126.545
# Skew:                          -0.521   Prob(JB):                     3.32e-28
# Kurtosis:                       2.898   Cond. No.                         50.3
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
X_test = valdf_standard_all[['Hinglish_cmi_scores_standardized',
       'Hinglish_burstiness_scores_standardized',
       'Hinglish_sp_scores_standardized',
        'symcom_scores_sent_standardized',
       'NOUN_symcom_standardized', 'AUX_symcom_standardized',
       'CCONJ_symcom_standardized', 'ADP_symcom_standardized',
       'NUM_symcom_standardized', 'PRON_symcom_standardized',
       'PART_symcom_standardized', 'VERB_symcom_standardized',
       'PROPN_symcom_standardized', 'SCONJ_symcom_standardized',
       'ADV_symcom_standardized', 'INTJ_symcom_standardized',
       'DET_symcom_standardized', 'ADJ_symcom_standardized',
       'symcom_+1_count_standardized', 'symcom_-1_count_standardized',
       'symcom_na_count_standardized', 'symcom_others_standardized']]

X_test_imputed_data = sim.transform(X_test.values)


predictions = model.predict(X_test_imputed_data)

print(predictions)
# Out:
# ------------------------------------------------------------
# NameError                  Traceback (most recent call last)
# <ipython-input-25-8b0f6202247c> in <module>
# ----> 1 X_test = valdf_standard_all[['Hinglish_cmi_scores_standardized',
#       2        'Hinglish_burstiness_scores_standardized',
#       3        'Hinglish_sp_scores_standardized',
#       4         'symcom_scores_sent_standardized',
#       5        'NOUN_symcom_standardized', 'AUX_symcom_standardized',
#
# NameError: name 'valdf_standard_all' is not defined

# %%
X = traindf_standard_all[['Hinglish_cmi_scores_standardized',
       'Hinglish_burstiness_scores_standardized',
       'Hinglish_sp_scores_standardized',
        'symcom_scores_sent_standardized',
       'NOUN_symcom_standardized', 'AUX_symcom_standardized',
       'CCONJ_symcom_standardized', 'ADP_symcom_standardized',
       'NUM_symcom_standardized', 'PRON_symcom_standardized',
       'PART_symcom_standardized', 'VERB_symcom_standardized',
       'PROPN_symcom_standardized', 'SCONJ_symcom_standardized',
       'ADV_symcom_standardized', 'INTJ_symcom_standardized',
       'DET_symcom_standardized', 'ADJ_symcom_standardized',
       'symcom_+1_count_standardized', 'symcom_-1_count_standardized',
       'symcom_na_count_standardized', 'symcom_others_standardized']]


sim = SimpleImputer(missing_values=np.nan, strategy='mean')

X_imputed_data = sim.fit_transform(X.values)

y = traindf_standard_all["Disagreement"]

model = sm.OLS(y, X_imputed_data).fit()
predictions = model.predict(X) # make the predictions by the model

# Print out the statistics
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:           Disagreement   R-squared:                       0.076
# Model:                            OLS   Adj. R-squared:                  0.069
# Method:                 Least Squares   F-statistic:                     10.81
# Date:                Mon, 09 May 2022   Prob (F-statistic):           6.79e-35
# Time:                        23:30:44   Log-Likelihood:                -5568.4
# No. Observations:                2766   AIC:                         1.118e+04
# Df Residuals:                    2744   BIC:                         1.131e+04
# Df Model:                          21
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# x1             0.0221      0.246      0.090      0.928      -0.460       0.505
# x2            -0.1409      0.293     -0.481      0.630      -0.715       0.433
# x3            -0.1924      0.674     -0.286      0.775      -1.514       1.129
# x4             0.4496      0.280      1.604      0.109      -0.100       0.999
# x5            -1.3302      0.180     -7.384      0.000      -1.683      -0.977
# x6            -0.1778      0.306     -0.580      0.562      -0.778       0.423
# x7            -0.7383      0.238     -3.105      0.002      -1.204      -0.272
# x8             0.2958      0.283      1.044      0.297      -0.260       0.851
# x9             0.2720      0.346      0.786      0.432      -0.407       0.951
# x10           -0.3807      0.259     -1.473      0.141      -0.888       0.126
# x11            0.4622      0.410      1.127      0.260      -0.342       1.267
# x12            0.0755      0.192      0.392      0.695      -0.302       0.453
# x13           -0.0604      0.216     -0.280      0.780      -0.484       0.363
# x14           -0.7916      0.740     -1.070      0.285      -2.242       0.659
# x15           -0.1454      0.221     -0.657      0.511      -0.579       0.288
# x16           -0.3233      0.666     -0.486      0.627      -1.628       0.982
# x17           -0.0631      0.235     -0.268      0.789      -0.525       0.398
# x18           -0.6410      0.150     -4.278      0.000      -0.935      -0.347
# x19            2.5583      0.750      3.412      0.001       1.088       4.029
# x20            3.2525      0.454      7.165      0.000       2.362       4.143
# x21            2.6236      0.411      6.382      0.000       1.817       3.430
# x22            2.4992      0.629      3.973      0.000       1.266       3.733
# ==============================================================================
# Omnibus:                      285.751   Durbin-Watson:                   1.976
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              378.283
# Skew:                           0.870   Prob(JB):                     7.19e-83
# Kurtosis:                       3.507   Cond. No.                         50.3
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
subdf = traindf_standard_all[['Hinglish_cmi_scores_standardized',
       'Hinglish_burstiness_scores_standardized',
       'Hinglish_sp_scores_standardized', 'symcom_scores_sent_standardized',
       'NOUN_symcom_standardized', 'AUX_symcom_standardized',
       'CCONJ_symcom_standardized', 'ADP_symcom_standardized',
       'NUM_symcom_standardized', 'PRON_symcom_standardized',
       'PART_symcom_standardized', 'VERB_symcom_standardized',
       'PROPN_symcom_standardized', 'SCONJ_symcom_standardized',
       'ADV_symcom_standardized', 'INTJ_symcom_standardized',
       'DET_symcom_standardized', 'ADJ_symcom_standardized',
       'symcom_+1_count_standardized', 'symcom_-1_count_standardized',
       'symcom_na_count_standardized', 'symcom_others_standardized']]

for col in subdf.columns:
    subdf[col] = pd.to_numeric(traindf_standard_all[col],errors='coerce')

subdf.boxplot(rot=90)
# Out:
# /home/tanmay.sachan/anaconda3/envs/nlp/lib/python3.7/site-packages/pandas/core/frame.py:3607: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._set_item(key, value)
# <AxesSubplot:>

# %%
traindf.columns
# Out:
# Index(['index', 'English', 'Hindi', 'Hinglish', 'Average rating',
#        'Disagreement', 'hum_gen', 'Hinglish_csnliop', 'hum_gen_csnliop',
#        'Hinglish_norm', 'Hinglish_lid', 'hum_gen_norm', 'hum_gen_lid',
#        'Hinglish_pos', 'hum_gen_pos', 'Hinglish_cmi_scores',
#        'Hinglish_burstiness_scores', 'Hinglish_sp_scores', 'symcom_scores_pos',
#        'symcom_scores_sent', 'NOUN_symcom', 'AUX_symcom', 'CCONJ_symcom',
#        'ADP_symcom', 'NUM_symcom', 'PRON_symcom', 'PART_symcom', 'VERB_symcom',
#        'PROPN_symcom', 'SCONJ_symcom', 'ADV_symcom', 'INTJ_symcom',
#        'DET_symcom', 'ADJ_symcom', 'symcom_+1_count', 'symcom_-1_count',
#        'symcom_na_count', 'symcom_others', 'Hinglish_length',
#        'Hingilish_xlmr_scores', 'hum_gen_tokens', 'hum_gen_xlmr_scores',
#        'xlm_r_ppl_scores_delta', 'eucl', 'cityblock', 'cosine'],
#       dtype='object')

# %% [markdown]
# # MLP Regressor

# %%
X = traindf_standard_all[['Hinglish_cmi_scores_standardized',
       'Hinglish_burstiness_scores_standardized',
       'Hinglish_sp_scores_standardized',
        'symcom_scores_sent_standardized',
       'NOUN_symcom_standardized', 'AUX_symcom_standardized',
       'CCONJ_symcom_standardized', 'ADP_symcom_standardized',
       'NUM_symcom_standardized', 'PRON_symcom_standardized',
       'PART_symcom_standardized', 'VERB_symcom_standardized',
       'PROPN_symcom_standardized', 'SCONJ_symcom_standardized',
       'ADV_symcom_standardized', 'INTJ_symcom_standardized',
       'DET_symcom_standardized', 'ADJ_symcom_standardized',
       'symcom_+1_count_standardized', 'symcom_-1_count_standardized',
       'symcom_na_count_standardized', 'symcom_others_standardized',
       'xlm_r_ppl_scores_delta_standardized', 'Hinglish_length_standardized',
         'eucl_standardized', 'cityblock_standardized', 'cosine_standardized']]


sim = SimpleImputer(missing_values=np.nan, strategy='mean')

X_imputed_data = sim.fit_transform(X.values)

y = traindf_standard_all["Average rating"]

regr = MLPRegressor(random_state=1, max_iter=10000, verbose = True).fit(X_imputed_data, y)


X_test = testdf_standard_all[['Hinglish_cmi_scores_standardized',
       'Hinglish_burstiness_scores_standardized',
       'Hinglish_sp_scores_standardized',
        'symcom_scores_sent_standardized',
       'NOUN_symcom_standardized', 'AUX_symcom_standardized',
       'CCONJ_symcom_standardized', 'ADP_symcom_standardized',
       'NUM_symcom_standardized', 'PRON_symcom_standardized',
       'PART_symcom_standardized', 'VERB_symcom_standardized',
       'PROPN_symcom_standardized', 'SCONJ_symcom_standardized',
       'ADV_symcom_standardized', 'INTJ_symcom_standardized',
       'DET_symcom_standardized', 'ADJ_symcom_standardized',
       'symcom_+1_count_standardized', 'symcom_-1_count_standardized',
       'symcom_na_count_standardized', 'symcom_others_standardized',
        'xlm_r_ppl_scores_delta_standardized', 'Hinglish_length_standardized',
         'eucl_standardized', 'cityblock_standardized', 'cosine_standardized']]

X_test_imputed = sim.transform(X_test)

predictions_test = regr.predict(X_test_imputed)

predictions_test_round = [round(el) for el in predictions_test]
# Out:
# Iteration 1, loss = 24.17801430
# Iteration 2, loss = 18.40914474
# Iteration 3, loss = 12.78391379
# Iteration 4, loss = 7.55434110
# Iteration 5, loss = 3.77167871
# Iteration 6, loss = 2.02359593
# Iteration 7, loss = 1.67999240
# Iteration 8, loss = 1.66381776
# Iteration 9, loss = 1.62706232
# Iteration 10, loss = 1.59530208
# Iteration 11, loss = 1.57124633
# Iteration 12, loss = 1.54762647
# Iteration 13, loss = 1.52645700
# Iteration 14, loss = 1.50590332
# Iteration 15, loss = 1.48658055
# Iteration 16, loss = 1.46771125
# Iteration 17, loss = 1.45144905
# Iteration 18, loss = 1.43519376
# Iteration 19, loss = 1.42062776
# Iteration 20, loss = 1.40611770
# Iteration 21, loss = 1.39247877
# Iteration 22, loss = 1.38002538
# Iteration 23, loss = 1.36825381
# Iteration 24, loss = 1.35658467
# Iteration 25, loss = 1.34496287
# Iteration 26, loss = 1.33384294
# Iteration 27, loss = 1.32222242
# Iteration 28, loss = 1.31047679
# Iteration 29, loss = 1.29858348
# Iteration 30, loss = 1.28593783
# Iteration 31, loss = 1.27409927
# Iteration 32, loss = 1.26253740
# Iteration 33, loss = 1.25348165
# Iteration 34, loss = 1.24355639
# Iteration 35, loss = 1.23522556
# Iteration 36, loss = 1.22875156
# Iteration 37, loss = 1.22099714
# Iteration 38, loss = 1.21389036
# Iteration 39, loss = 1.20844022
# Iteration 40, loss = 1.20399469
# Iteration 41, loss = 1.19804588
# Iteration 42, loss = 1.19526450
# Iteration 43, loss = 1.19147064
# Iteration 44, loss = 1.18768389
# Iteration 45, loss = 1.18549130
# Iteration 46, loss = 1.18305959
# Iteration 47, loss = 1.18068839
# Iteration 48, loss = 1.17840861
# Iteration 49, loss = 1.17636801
# Iteration 50, loss = 1.17527720
# Iteration 51, loss = 1.17431105
# Iteration 52, loss = 1.17170146
# Iteration 53, loss = 1.16995544
# Iteration 54, loss = 1.16941612
# Iteration 55, loss = 1.16754809
# Iteration 56, loss = 1.16672991
# Iteration 57, loss = 1.16522440
# Iteration 58, loss = 1.16378187
# Iteration 59, loss = 1.16294955
# Iteration 60, loss = 1.16233644
# Iteration 61, loss = 1.16130193
# Iteration 62, loss = 1.16271539
# Iteration 63, loss = 1.16024836
# Iteration 64, loss = 1.16024586
# Iteration 65, loss = 1.15802163
# Iteration 66, loss = 1.15708910
# Iteration 67, loss = 1.15777607
# Iteration 68, loss = 1.15626834
# Iteration 69, loss = 1.15575221
# Iteration 70, loss = 1.15414804
# Iteration 71, loss = 1.15367332
# Iteration 72, loss = 1.15301600
# Iteration 73, loss = 1.15284306
# Iteration 74, loss = 1.15259717
# Iteration 75, loss = 1.15228622
# Iteration 76, loss = 1.14985470
# Iteration 77, loss = 1.14987842
# Iteration 78, loss = 1.15080371
# Iteration 79, loss = 1.15336096
# Iteration 80, loss = 1.14752162
# Iteration 81, loss = 1.14654219
# Iteration 82, loss = 1.14707207
# Iteration 83, loss = 1.14843810
# Iteration 84, loss = 1.14726332
# Iteration 85, loss = 1.14421270
# Iteration 86, loss = 1.14653771
# Iteration 87, loss = 1.14784685
# Iteration 88, loss = 1.15174151
# Iteration 89, loss = 1.14449636
# Iteration 90, loss = 1.14393463
# Iteration 91, loss = 1.14241845
# Iteration 92, loss = 1.14305157
# Iteration 93, loss = 1.14379348
# Iteration 94, loss = 1.14178932
# Iteration 95, loss = 1.14075327
# Iteration 96, loss = 1.14036929
# Iteration 97, loss = 1.13885515
# Iteration 98, loss = 1.13834267
# Iteration 99, loss = 1.13933861
# Iteration 100, loss = 1.13790014
# Iteration 101, loss = 1.13898608
# Iteration 102, loss = 1.13876792
# Iteration 103, loss = 1.13809173
# Iteration 104, loss = 1.13885306
# Iteration 105, loss = 1.13449039
# Iteration 106, loss = 1.13835261
# Iteration 107, loss = 1.13442573
# Iteration 108, loss = 1.13531972
# Iteration 109, loss = 1.13372036
# Iteration 110, loss = 1.13271928
# Iteration 111, loss = 1.13440900
# Iteration 112, loss = 1.13097698
# Iteration 113, loss = 1.13505814
# Iteration 114, loss = 1.13357198
# Iteration 115, loss = 1.13123259
# Iteration 116, loss = 1.13078612
# Iteration 117, loss = 1.13243947
# Iteration 118, loss = 1.13215665
# Iteration 119, loss = 1.13141272
# Iteration 120, loss = 1.13214843
# Iteration 121, loss = 1.12959323
# Iteration 122, loss = 1.13026531
# Iteration 123, loss = 1.12897837
# Iteration 124, loss = 1.12789222
# Iteration 125, loss = 1.12798942
# Iteration 126, loss = 1.12899595
# Iteration 127, loss = 1.13029719
# Iteration 128, loss = 1.12811562
# Iteration 129, loss = 1.12558880
# Iteration 130, loss = 1.12601470
# Iteration 131, loss = 1.12674771
# Iteration 132, loss = 1.12454047
# Iteration 133, loss = 1.12325219
# Iteration 134, loss = 1.12790115
# Iteration 135, loss = 1.12831220
# Iteration 136, loss = 1.12493396
# Iteration 137, loss = 1.12644777
# Iteration 138, loss = 1.12794195
# Iteration 139, loss = 1.12437657
# Iteration 140, loss = 1.12379205
# Iteration 141, loss = 1.12257953
# Iteration 142, loss = 1.12246842
# Iteration 143, loss = 1.12469590
# Iteration 144, loss = 1.12243995
# Iteration 145, loss = 1.12167439
# Iteration 146, loss = 1.12133554
# Iteration 147, loss = 1.12189006
# Iteration 148, loss = 1.12270611
# Iteration 149, loss = 1.12325166
# Iteration 150, loss = 1.11837390
# Iteration 151, loss = 1.11908247
# Iteration 152, loss = 1.12188494
# Iteration 153, loss = 1.11690666
# Iteration 154, loss = 1.11641854
# Iteration 155, loss = 1.11851536
# Iteration 156, loss = 1.11896217
# Iteration 157, loss = 1.11819474
# Iteration 158, loss = 1.11851854
# Iteration 159, loss = 1.11951224
# Iteration 160, loss = 1.11524952
# Iteration 161, loss = 1.11563038
# Iteration 162, loss = 1.11451879
# Iteration 163, loss = 1.11549265
# Iteration 164, loss = 1.11356501
# Iteration 165, loss = 1.11457731
# Iteration 166, loss = 1.11273049
# Iteration 167, loss = 1.11251060
# Iteration 168, loss = 1.11157573
# Iteration 169, loss = 1.11383135
# Iteration 170, loss = 1.11586106
# Iteration 171, loss = 1.11313098
# Iteration 172, loss = 1.11205642
# Iteration 173, loss = 1.11066147
# Iteration 174, loss = 1.10986387
# Iteration 175, loss = 1.11049096
# Iteration 176, loss = 1.10867116
# Iteration 177, loss = 1.10849047
# Iteration 178, loss = 1.11315209
# Iteration 179, loss = 1.10887683
# Iteration 180, loss = 1.10925958
# Iteration 181, loss = 1.10765055
# Iteration 182, loss = 1.10917951
# Iteration 183, loss = 1.11544720
# Iteration 184, loss = 1.11955776
# Iteration 185, loss = 1.11314708
# Iteration 186, loss = 1.10984061
# Iteration 187, loss = 1.10554097
# Iteration 188, loss = 1.10620676
# Iteration 189, loss = 1.10916881
# Iteration 190, loss = 1.10578551
# Iteration 191, loss = 1.10358831
# Iteration 192, loss = 1.10876720
# Iteration 193, loss = 1.10567797
# Iteration 194, loss = 1.10395480
# Iteration 195, loss = 1.10420807
# Iteration 196, loss = 1.10315787
# Iteration 197, loss = 1.10201604
# Iteration 198, loss = 1.10254257
# Iteration 199, loss = 1.10461820
# Iteration 200, loss = 1.10259607
# Iteration 201, loss = 1.10071489
# Iteration 202, loss = 1.10470214
# Iteration 203, loss = 1.09928548
# Iteration 204, loss = 1.10218293
# Iteration 205, loss = 1.10210654
# Iteration 206, loss = 1.09843774
# Iteration 207, loss = 1.09787109
# Iteration 208, loss = 1.10059757
# Iteration 209, loss = 1.09779272
# Iteration 210, loss = 1.09805010
# Iteration 211, loss = 1.09749983
# Iteration 212, loss = 1.09648716
# Iteration 213, loss = 1.09739214
# Iteration 214, loss = 1.09805885
# Iteration 215, loss = 1.09698611
# Iteration 216, loss = 1.10017463
# Iteration 217, loss = 1.09662863
# Iteration 218, loss = 1.09565915
# Iteration 219, loss = 1.09550986
# Iteration 220, loss = 1.09327910
# Iteration 221, loss = 1.09575089
# Iteration 222, loss = 1.09215322
# Iteration 223, loss = 1.09363826
# Iteration 224, loss = 1.09332899
# Iteration 225, loss = 1.09488632
# Iteration 226, loss = 1.09288232
# Iteration 227, loss = 1.09111188
# Iteration 228, loss = 1.09152234
# Iteration 229, loss = 1.09094903
# Iteration 230, loss = 1.09187194
# Iteration 231, loss = 1.09083702
# Iteration 232, loss = 1.09765162
# Iteration 233, loss = 1.09021779
# Iteration 234, loss = 1.08932024
# Iteration 235, loss = 1.08765769
# Iteration 236, loss = 1.09201403
# Iteration 237, loss = 1.09350738
# Iteration 238, loss = 1.08646340
# Iteration 239, loss = 1.08692525
# Iteration 240, loss = 1.08639723
# Iteration 241, loss = 1.09261095
# Iteration 242, loss = 1.08989610
# Iteration 243, loss = 1.08560762
# Iteration 244, loss = 1.08515351
# Iteration 245, loss = 1.08383861
# Iteration 246, loss = 1.08720129
# Iteration 247, loss = 1.08525120
# Iteration 248, loss = 1.08930788
# Iteration 249, loss = 1.08367518
# Iteration 250, loss = 1.08478483
# Iteration 251, loss = 1.08343388
# Iteration 252, loss = 1.08208947
# Iteration 253, loss = 1.08323082
# Iteration 254, loss = 1.08387587
# Iteration 255, loss = 1.08276814
# Iteration 256, loss = 1.08012339
# Iteration 257, loss = 1.08699607
# Iteration 258, loss = 1.08556949
# Iteration 259, loss = 1.08510471
# Iteration 260, loss = 1.09631720
# Iteration 261, loss = 1.09099647
# Iteration 262, loss = 1.08463920
# Iteration 263, loss = 1.07974078
# Iteration 264, loss = 1.07807799
# Iteration 265, loss = 1.08197596
# Iteration 266, loss = 1.07700845
# Iteration 267, loss = 1.07850335
# Iteration 268, loss = 1.07653222
# Iteration 269, loss = 1.07775198
# Iteration 270, loss = 1.07579262
# Iteration 271, loss = 1.07631080
# Iteration 272, loss = 1.07662290
# Iteration 273, loss = 1.07648544
# Iteration 274, loss = 1.07553873
# Iteration 275, loss = 1.07546989
# Iteration 276, loss = 1.07539384
# Iteration 277, loss = 1.07549183
# Iteration 278, loss = 1.07385514
# Iteration 279, loss = 1.07872182
# Iteration 280, loss = 1.07840588
# Iteration 281, loss = 1.07347725
# Iteration 282, loss = 1.07944743
# Iteration 283, loss = 1.07148579
# Iteration 284, loss = 1.07312827
# Iteration 285, loss = 1.07266801
# Iteration 286, loss = 1.07135066
# Iteration 287, loss = 1.07089774
# Iteration 288, loss = 1.07137107
# Iteration 289, loss = 1.06995850
# Iteration 290, loss = 1.07317588
# Iteration 291, loss = 1.07336645
# Iteration 292, loss = 1.06870192
# Iteration 293, loss = 1.07069698
# Iteration 294, loss = 1.07074799
# Iteration 295, loss = 1.06923830
# Iteration 296, loss = 1.07387146
# Iteration 297, loss = 1.06875265
# Iteration 298, loss = 1.06556291
# Iteration 299, loss = 1.06743477
# Iteration 300, loss = 1.06861134
# Iteration 301, loss = 1.06781811
# Iteration 302, loss = 1.06497532
# Iteration 303, loss = 1.06740399
# Iteration 304, loss = 1.06291626
# Iteration 305, loss = 1.06432360
# Iteration 306, loss = 1.06385122
# Iteration 307, loss = 1.06374740
# Iteration 308, loss = 1.06219292
# Iteration 309, loss = 1.06377256
# Iteration 310, loss = 1.06120163
# Iteration 311, loss = 1.06179687
# Iteration 312, loss = 1.07147844
# Iteration 313, loss = 1.06885594
# Iteration 314, loss = 1.06825953
# Iteration 315, loss = 1.06203411
# Iteration 316, loss = 1.06470857
# Iteration 317, loss = 1.05943543
# Iteration 318, loss = 1.05926129
# Iteration 319, loss = 1.06038657
# Iteration 320, loss = 1.05900357
# Iteration 321, loss = 1.05869839
# Iteration 322, loss = 1.05858190
# Iteration 323, loss = 1.05857526
# Iteration 324, loss = 1.06324282
# Iteration 325, loss = 1.06004018
# Iteration 326, loss = 1.05631735
# Iteration 327, loss = 1.05560648
# Iteration 328, loss = 1.05872700
# Iteration 329, loss = 1.05797445
# Iteration 330, loss = 1.05495332
# Iteration 331, loss = 1.05525879
# Iteration 332, loss = 1.05905457
# Iteration 333, loss = 1.05241456
# Iteration 334, loss = 1.05947191
# Iteration 335, loss = 1.05817067
# Iteration 336, loss = 1.05173753
# Iteration 337, loss = 1.05457223
# Iteration 338, loss = 1.05869878
# Iteration 339, loss = 1.05401368
# Iteration 340, loss = 1.05279813
# Iteration 341, loss = 1.05472896
# Iteration 342, loss = 1.05014176
# Iteration 343, loss = 1.04810183
# Iteration 344, loss = 1.04897160
# Iteration 345, loss = 1.04988357
# Iteration 346, loss = 1.04752762
# Iteration 347, loss = 1.05029647
# Iteration 348, loss = 1.05405712
# Iteration 349, loss = 1.05741153
# Iteration 350, loss = 1.04900742
# Iteration 351, loss = 1.04474944
# Iteration 352, loss = 1.04401148
# Iteration 353, loss = 1.04430897
# Iteration 354, loss = 1.04500826
# Iteration 355, loss = 1.04433731
# Iteration 356, loss = 1.04929505
# Iteration 357, loss = 1.04459842
# Iteration 358, loss = 1.04353907
# Iteration 359, loss = 1.04203017
# Iteration 360, loss = 1.04200798
# Iteration 361, loss = 1.04048664
# Iteration 362, loss = 1.03969555
# Iteration 363, loss = 1.03953348
# Iteration 364, loss = 1.03947134
# Iteration 365, loss = 1.04033782
# Iteration 366, loss = 1.04097176
# Iteration 367, loss = 1.04156674
# Iteration 368, loss = 1.04061469
# Iteration 369, loss = 1.03830769
# Iteration 370, loss = 1.03836870
# Iteration 371, loss = 1.03827904
# Iteration 372, loss = 1.03548075
# Iteration 373, loss = 1.03538607
# Iteration 374, loss = 1.03808459
# Iteration 375, loss = 1.03299259
# Iteration 376, loss = 1.03650268
# Iteration 377, loss = 1.03791204
# Iteration 378, loss = 1.03705628
# Iteration 379, loss = 1.03503784
# Iteration 380, loss = 1.03498184
# Iteration 381, loss = 1.03422220
# Iteration 382, loss = 1.03711491
# Iteration 383, loss = 1.03265881
# Iteration 384, loss = 1.03642962
# Iteration 385, loss = 1.02943145
# Iteration 386, loss = 1.02937384
# Iteration 387, loss = 1.03134979
# Iteration 388, loss = 1.03529890
# Iteration 389, loss = 1.03138321
# Iteration 390, loss = 1.03523132
# Iteration 391, loss = 1.03427985
# Iteration 392, loss = 1.03163753
# Iteration 393, loss = 1.03335642
# Iteration 394, loss = 1.03323199
# Iteration 395, loss = 1.02633530
# Iteration 396, loss = 1.02983764
# Iteration 397, loss = 1.02904550
# Iteration 398, loss = 1.02470158
# Iteration 399, loss = 1.02753559
# Iteration 400, loss = 1.02352439
# Iteration 401, loss = 1.02446578
# Iteration 402, loss = 1.02215238
# Iteration 403, loss = 1.02475450
# Iteration 404, loss = 1.02351271
# Iteration 405, loss = 1.02117930
# Iteration 406, loss = 1.02193742
# Iteration 407, loss = 1.01946644
# Iteration 408, loss = 1.02149696
# Iteration 409, loss = 1.01941499
# Iteration 410, loss = 1.01941304
# Iteration 411, loss = 1.02004142
# Iteration 412, loss = 1.01900274
# Iteration 413, loss = 1.01883663
# Iteration 414, loss = 1.01682606
# Iteration 415, loss = 1.01808598
# Iteration 416, loss = 1.02739709
# Iteration 417, loss = 1.01807270
# Iteration 418, loss = 1.02061559
# Iteration 419, loss = 1.01577266
# Iteration 420, loss = 1.01798778
# Iteration 421, loss = 1.02392752
# Iteration 422, loss = 1.02174302
# Iteration 423, loss = 1.01614053
# Iteration 424, loss = 1.01578139
# Iteration 425, loss = 1.01641634
# Iteration 426, loss = 1.01150351
# Iteration 427, loss = 1.01319716
# Iteration 428, loss = 1.01149509
# Iteration 429, loss = 1.01000909
# Iteration 430, loss = 1.00979435
# Iteration 431, loss = 1.01046270
# Iteration 432, loss = 1.01905775
# Iteration 433, loss = 1.01038530
# Iteration 434, loss = 1.00911668
# Iteration 435, loss = 1.01094045
# Iteration 436, loss = 1.00916776
# Iteration 437, loss = 1.00783614
# Iteration 438, loss = 1.00673673
# Iteration 439, loss = 1.00806197
# Iteration 440, loss = 1.01009577
# Iteration 441, loss = 1.00823211
# Iteration 442, loss = 1.00630468
# Iteration 443, loss = 1.00504985
# Iteration 444, loss = 1.00628165
# Iteration 445, loss = 1.00284578
# Iteration 446, loss = 1.00509496
# Iteration 447, loss = 1.00437950
# Iteration 448, loss = 1.00279224
# Iteration 449, loss = 1.00543600
# Iteration 450, loss = 1.00286301
# Iteration 451, loss = 1.00210531
# Iteration 452, loss = 1.00039702
# Iteration 453, loss = 1.00472782
# Iteration 454, loss = 1.00461698
# Iteration 455, loss = 1.01025177
# Iteration 456, loss = 1.01503899
# Iteration 457, loss = 1.00176188
# Iteration 458, loss = 1.00075283
# Iteration 459, loss = 1.00220593
# Iteration 460, loss = 0.99704185
# Iteration 461, loss = 0.99551841
# Iteration 462, loss = 0.99443873
# Iteration 463, loss = 0.99491958
# Iteration 464, loss = 0.99621210
# Iteration 465, loss = 0.99607108
# Iteration 466, loss = 0.99392806
# Iteration 467, loss = 0.99373030
# Iteration 468, loss = 0.99541937
# Iteration 469, loss = 0.99252213
# Iteration 470, loss = 0.99171574
# Iteration 471, loss = 0.99238038
# Iteration 472, loss = 0.99199289
# Iteration 473, loss = 0.98975512
# Iteration 474, loss = 0.98988953
# Iteration 475, loss = 0.99180021
# Iteration 476, loss = 0.99443967
# Iteration 477, loss = 0.98937165
# Iteration 478, loss = 0.98822850
# Iteration 479, loss = 0.99021217
# Iteration 480, loss = 0.98725435
# Iteration 481, loss = 0.98903694
# Iteration 482, loss = 0.99383318
# Iteration 483, loss = 0.99188380
# Iteration 484, loss = 0.99615490
# Iteration 485, loss = 0.98768909
# Iteration 486, loss = 0.99270682
# Iteration 487, loss = 0.98596474
# Iteration 488, loss = 0.98559821
# Iteration 489, loss = 0.98463390
# Iteration 490, loss = 0.98278751
# Iteration 491, loss = 0.98647210
# Iteration 492, loss = 0.98459943
# Iteration 493, loss = 0.98436378
# Iteration 494, loss = 0.98720770
# Iteration 495, loss = 0.99402520
# Iteration 496, loss = 0.98213197
# Iteration 497, loss = 0.97957252
# Iteration 498, loss = 0.98023930
# Iteration 499, loss = 0.97970681
# Iteration 500, loss = 0.98187971
# Iteration 501, loss = 0.98015669
# Iteration 502, loss = 0.98490681
# Iteration 503, loss = 0.98398335
# Iteration 504, loss = 0.97936960
# Iteration 505, loss = 0.98005724
# Iteration 506, loss = 0.98292258
# Iteration 507, loss = 0.98691742
# Iteration 508, loss = 0.97881354
# Iteration 509, loss = 0.97469048
# Iteration 510, loss = 0.97643791
# Iteration 511, loss = 0.97301869
# Iteration 512, loss = 0.97567590
# Iteration 513, loss = 0.97687699
# Iteration 514, loss = 0.97242007
# Iteration 515, loss = 0.97635061
# Iteration 516, loss = 0.98045130
# Iteration 517, loss = 0.97351558
# Iteration 518, loss = 0.97259521
# Iteration 519, loss = 0.97878233
# Iteration 520, loss = 0.97655718
# Iteration 521, loss = 0.97439254
# Iteration 522, loss = 0.96970284
# Iteration 523, loss = 0.97876463
# Iteration 524, loss = 0.97349671
# Iteration 525, loss = 0.97884788
# Iteration 526, loss = 0.97460650
# Iteration 527, loss = 0.97090898
# Iteration 528, loss = 0.96858129
# Iteration 529, loss = 0.96563707
# Iteration 530, loss = 0.97121457
# Iteration 531, loss = 0.96499211
# Iteration 532, loss = 0.96586558
# Iteration 533, loss = 0.96511733
# Iteration 534, loss = 0.96623745
# Iteration 535, loss = 0.97607775
# Iteration 536, loss = 0.97682499
# Iteration 537, loss = 0.97258358
# Iteration 538, loss = 0.96621783
# Iteration 539, loss = 0.96470601
# Iteration 540, loss = 0.96420211
# Iteration 541, loss = 0.96392021
# Iteration 542, loss = 0.96264382
# Iteration 543, loss = 0.97101327
# Iteration 544, loss = 0.96343792
# Iteration 545, loss = 0.95966715
# Iteration 546, loss = 0.96727179
# Iteration 547, loss = 0.96364395
# Iteration 548, loss = 0.96017900
# Iteration 549, loss = 0.96144807
# Iteration 550, loss = 0.95980716
# Iteration 551, loss = 0.95919273
# Iteration 552, loss = 0.95876431
# Iteration 553, loss = 0.95794558
# Iteration 554, loss = 0.95848405
# Iteration 555, loss = 0.95716667
# Iteration 556, loss = 0.95876818
# Iteration 557, loss = 0.95700268
# Iteration 558, loss = 0.95580405
# Iteration 559, loss = 0.95567360
# Iteration 560, loss = 0.95636858
# Iteration 561, loss = 0.95527002
# Iteration 562, loss = 0.95409754
# Iteration 563, loss = 0.95234024
# Iteration 564, loss = 0.96178229
# Iteration 565, loss = 0.95361232
# Iteration 566, loss = 0.95315569
# Iteration 567, loss = 0.95697405
# Iteration 568, loss = 0.95865565
# Iteration 569, loss = 0.95245147
# Iteration 570, loss = 0.95629715
# Iteration 571, loss = 0.95264692
# Iteration 572, loss = 0.96062896
# Iteration 573, loss = 0.95552904
# Iteration 574, loss = 0.95140382
# Iteration 575, loss = 0.95338969
# Iteration 576, loss = 0.95084935
# Iteration 577, loss = 0.94982209
# Iteration 578, loss = 0.95900115
# Iteration 579, loss = 0.94800561
# Iteration 580, loss = 0.94916804
# Iteration 581, loss = 0.95550748
# Iteration 582, loss = 0.95701100
# Iteration 583, loss = 0.94693062
# Iteration 584, loss = 0.94997313
# Iteration 585, loss = 0.94949352
# Iteration 586, loss = 0.95739401
# Iteration 587, loss = 0.95270484
# Iteration 588, loss = 0.94729265
# Iteration 589, loss = 0.96000059
# Iteration 590, loss = 0.95069097
# Iteration 591, loss = 0.94534523
# Iteration 592, loss = 0.94747528
# Iteration 593, loss = 0.94630510
# Iteration 594, loss = 0.94579205
# Iteration 595, loss = 0.94455319
# Iteration 596, loss = 0.95255029
# Iteration 597, loss = 0.95006757
# Iteration 598, loss = 0.94629758
# Iteration 599, loss = 0.94402042
# Iteration 600, loss = 0.94343889
# Iteration 601, loss = 0.94337952
# Iteration 602, loss = 0.94157826
# Iteration 603, loss = 0.94579809
# Iteration 604, loss = 0.94448774
# Iteration 605, loss = 0.93937936
# Iteration 606, loss = 0.94028817
# Iteration 607, loss = 0.94444863
# Iteration 608, loss = 0.94137643
# Iteration 609, loss = 0.94462957
# Iteration 610, loss = 0.94179890
# Iteration 611, loss = 0.94044924
# Iteration 612, loss = 0.93728193
# Iteration 613, loss = 0.93852419
# Iteration 614, loss = 0.94156720
# Iteration 615, loss = 0.94129822
# Iteration 616, loss = 0.93818419
# Iteration 617, loss = 0.93885531
# Iteration 618, loss = 0.93638718
# Iteration 619, loss = 0.94080091
# Iteration 620, loss = 0.94023733
# Iteration 621, loss = 0.93741385
# Iteration 622, loss = 0.93627402
# Iteration 623, loss = 0.93609529
# Iteration 624, loss = 0.93275194
# Iteration 625, loss = 0.93152912
# Iteration 626, loss = 0.93715619
# Iteration 627, loss = 0.93634354
# Iteration 628, loss = 0.93481840
# Iteration 629, loss = 0.93410388
# Iteration 630, loss = 0.93217473
# Iteration 631, loss = 0.93259028
# Iteration 632, loss = 0.93085340
# Iteration 633, loss = 0.93342924
# Iteration 634, loss = 0.93505075
# Iteration 635, loss = 0.93021901
# Iteration 636, loss = 0.93038226
# Iteration 637, loss = 0.93131461
# Iteration 638, loss = 0.92935810
# Iteration 639, loss = 0.94288799
# Iteration 640, loss = 0.93775233
# Iteration 641, loss = 0.93548111
# Iteration 642, loss = 0.92793162
# Iteration 643, loss = 0.92875058
# Iteration 644, loss = 0.93487382
# Iteration 645, loss = 0.93305479
# Iteration 646, loss = 0.93434357
# Iteration 647, loss = 0.93270536
# Iteration 648, loss = 0.92921134
# Iteration 649, loss = 0.92952251
# Iteration 650, loss = 0.93114072
# Iteration 651, loss = 0.93159186
# Iteration 652, loss = 0.93866141
# Iteration 653, loss = 0.93487802
# Training loss did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.

# %%
with open('test_predictions_avg_rating.txt','w') as f:
    for el in predictions_test_round:
        f.write(str(el)+"\n")

# %%
len(open('test_predictions_avg_rating.txt','r').readlines())
# Out:
# 791

# %%
X = traindf_standard_all[['Hinglish_cmi_scores_standardized',
       'Hinglish_burstiness_scores_standardized',
       'Hinglish_sp_scores_standardized',
        'symcom_scores_sent_standardized',
       'NOUN_symcom_standardized', 'AUX_symcom_standardized',
       'CCONJ_symcom_standardized', 'ADP_symcom_standardized',
       'NUM_symcom_standardized', 'PRON_symcom_standardized',
       'PART_symcom_standardized', 'VERB_symcom_standardized',
       'PROPN_symcom_standardized', 'SCONJ_symcom_standardized',
       'ADV_symcom_standardized', 'INTJ_symcom_standardized',
       'DET_symcom_standardized', 'ADJ_symcom_standardized',
       'symcom_+1_count_standardized', 'symcom_-1_count_standardized',
       'symcom_na_count_standardized', 'symcom_others_standardized',
        'xlm_r_ppl_scores_delta_standardized', 'Hinglish_length_standardized',
                         'eucl_standardized', 'cityblock_standardized', 'cosine_standardized']]


sim = SimpleImputer(missing_values=np.nan, strategy='mean')

X_imputed_data = sim.fit_transform(X.values)

y = traindf_standard_all["Disagreement"]


regr = MLPRegressor(random_state=1, max_iter=10000, verbose = True).fit(X_imputed_data, y)


X_test = testdf_standard_all[['Hinglish_cmi_scores_standardized',
       'Hinglish_burstiness_scores_standardized',
       'Hinglish_sp_scores_standardized',
        'symcom_scores_sent_standardized',
       'NOUN_symcom_standardized', 'AUX_symcom_standardized',
       'CCONJ_symcom_standardized', 'ADP_symcom_standardized',
       'NUM_symcom_standardized', 'PRON_symcom_standardized',
       'PART_symcom_standardized', 'VERB_symcom_standardized',
       'PROPN_symcom_standardized', 'SCONJ_symcom_standardized',
       'ADV_symcom_standardized', 'INTJ_symcom_standardized',
       'DET_symcom_standardized', 'ADJ_symcom_standardized',
       'symcom_+1_count_standardized', 'symcom_-1_count_standardized',
       'symcom_na_count_standardized', 'symcom_others_standardized',
        'xlm_r_ppl_scores_delta_standardized', 'Hinglish_length_standardized',
                            'eucl_standardized', 'cityblock_standardized', 'cosine_standardized']]

X_test_imputed = sim.transform(X_test)

predictions_test = regr.predict(X_test_imputed)

predictions_test_round = [round(el) for el in predictions_test]
# Out:
# Iteration 1, loss = 3.71877854
# Iteration 2, loss = 2.42902651
# Iteration 3, loss = 1.88188967
# Iteration 4, loss = 1.82898339
# Iteration 5, loss = 1.78475296
# Iteration 6, loss = 1.75189929
# Iteration 7, loss = 1.72655204
# Iteration 8, loss = 1.70380681
# Iteration 9, loss = 1.68905646
# Iteration 10, loss = 1.67504873
# Iteration 11, loss = 1.66445552
# Iteration 12, loss = 1.65568996
# Iteration 13, loss = 1.64963205
# Iteration 14, loss = 1.64669183
# Iteration 15, loss = 1.63994020
# Iteration 16, loss = 1.63769006
# Iteration 17, loss = 1.63415561
# Iteration 18, loss = 1.63111488
# Iteration 19, loss = 1.62979319
# Iteration 20, loss = 1.62713072
# Iteration 21, loss = 1.62500184
# Iteration 22, loss = 1.62296043
# Iteration 23, loss = 1.62059179
# Iteration 24, loss = 1.62034718
# Iteration 25, loss = 1.61770410
# Iteration 26, loss = 1.61674766
# Iteration 27, loss = 1.61889456
# Iteration 28, loss = 1.61459864
# Iteration 29, loss = 1.61071372
# Iteration 30, loss = 1.61234885
# Iteration 31, loss = 1.61009674
# Iteration 32, loss = 1.61031038
# Iteration 33, loss = 1.61063260
# Iteration 34, loss = 1.60626850
# Iteration 35, loss = 1.60530322
# Iteration 36, loss = 1.60439896
# Iteration 37, loss = 1.60409712
# Iteration 38, loss = 1.60244209
# Iteration 39, loss = 1.60232598
# Iteration 40, loss = 1.59849864
# Iteration 41, loss = 1.59910467
# Iteration 42, loss = 1.59715694
# Iteration 43, loss = 1.59684411
# Iteration 44, loss = 1.59597222
# Iteration 45, loss = 1.59487109
# Iteration 46, loss = 1.59353174
# Iteration 47, loss = 1.59225729
# Iteration 48, loss = 1.59170142
# Iteration 49, loss = 1.59073707
# Iteration 50, loss = 1.58961618
# Iteration 51, loss = 1.58824126
# Iteration 52, loss = 1.58703573
# Iteration 53, loss = 1.58730760
# Iteration 54, loss = 1.58501148
# Iteration 55, loss = 1.58541053
# Iteration 56, loss = 1.58227021
# Iteration 57, loss = 1.58210385
# Iteration 58, loss = 1.58006914
# Iteration 59, loss = 1.58298465
# Iteration 60, loss = 1.58259550
# Iteration 61, loss = 1.57811579
# Iteration 62, loss = 1.57593530
# Iteration 63, loss = 1.57405686
# Iteration 64, loss = 1.57328953
# Iteration 65, loss = 1.57051889
# Iteration 66, loss = 1.57077973
# Iteration 67, loss = 1.56939297
# Iteration 68, loss = 1.56803743
# Iteration 69, loss = 1.56545774
# Iteration 70, loss = 1.56435661
# Iteration 71, loss = 1.56392096
# Iteration 72, loss = 1.56128646
# Iteration 73, loss = 1.56408942
# Iteration 74, loss = 1.56074019
# Iteration 75, loss = 1.55838270
# Iteration 76, loss = 1.55689403
# Iteration 77, loss = 1.55648120
# Iteration 78, loss = 1.55667216
# Iteration 79, loss = 1.55686733
# Iteration 80, loss = 1.55291846
# Iteration 81, loss = 1.55130266
# Iteration 82, loss = 1.55061652
# Iteration 83, loss = 1.55043703
# Iteration 84, loss = 1.55034314
# Iteration 85, loss = 1.54643041
# Iteration 86, loss = 1.54913526
# Iteration 87, loss = 1.54492554
# Iteration 88, loss = 1.54872417
# Iteration 89, loss = 1.54201109
# Iteration 90, loss = 1.54233447
# Iteration 91, loss = 1.54189773
# Iteration 92, loss = 1.53787810
# Iteration 93, loss = 1.53742149
# Iteration 94, loss = 1.53636058
# Iteration 95, loss = 1.53582629
# Iteration 96, loss = 1.53256385
# Iteration 97, loss = 1.53273356
# Iteration 98, loss = 1.53176476
# Iteration 99, loss = 1.53093485
# Iteration 100, loss = 1.52830611
# Iteration 101, loss = 1.53073851
# Iteration 102, loss = 1.52790937
# Iteration 103, loss = 1.52845147
# Iteration 104, loss = 1.52647151
# Iteration 105, loss = 1.52438956
# Iteration 106, loss = 1.52287981
# Iteration 107, loss = 1.52092630
# Iteration 108, loss = 1.52424480
# Iteration 109, loss = 1.52237014
# Iteration 110, loss = 1.51868055
# Iteration 111, loss = 1.52066100
# Iteration 112, loss = 1.51660625
# Iteration 113, loss = 1.51629963
# Iteration 114, loss = 1.51678800
# Iteration 115, loss = 1.51661555
# Iteration 116, loss = 1.51645876
# Iteration 117, loss = 1.52458816
# Iteration 118, loss = 1.51073862
# Iteration 119, loss = 1.50904123
# Iteration 120, loss = 1.51218081
# Iteration 121, loss = 1.51066418
# Iteration 122, loss = 1.50735925
# Iteration 123, loss = 1.50866959
# Iteration 124, loss = 1.50841842
# Iteration 125, loss = 1.50454977
# Iteration 126, loss = 1.50454032
# Iteration 127, loss = 1.50494140
# Iteration 128, loss = 1.50173759
# Iteration 129, loss = 1.50186884
# Iteration 130, loss = 1.50294185
# Iteration 131, loss = 1.49954301
# Iteration 132, loss = 1.49704802
# Iteration 133, loss = 1.49659652
# Iteration 134, loss = 1.49560576
# Iteration 135, loss = 1.49463562
# Iteration 136, loss = 1.49337498
# Iteration 137, loss = 1.49052804
# Iteration 138, loss = 1.49012945
# Iteration 139, loss = 1.48920410
# Iteration 140, loss = 1.48973852
# Iteration 141, loss = 1.49299975
# Iteration 142, loss = 1.48717792
# Iteration 143, loss = 1.48678703
# Iteration 144, loss = 1.48615715
# Iteration 145, loss = 1.48635643
# Iteration 146, loss = 1.48353008
# Iteration 147, loss = 1.48230767
# Iteration 148, loss = 1.48096376
# Iteration 149, loss = 1.48079275
# Iteration 150, loss = 1.47944448
# Iteration 151, loss = 1.47875283
# Iteration 152, loss = 1.47941727
# Iteration 153, loss = 1.47750844
# Iteration 154, loss = 1.47453449
# Iteration 155, loss = 1.47667973
# Iteration 156, loss = 1.47510204
# Iteration 157, loss = 1.47608938
# Iteration 158, loss = 1.47363447
# Iteration 159, loss = 1.47331725
# Iteration 160, loss = 1.47314724
# Iteration 161, loss = 1.47131052
# Iteration 162, loss = 1.46993904
# Iteration 163, loss = 1.46899188
# Iteration 164, loss = 1.46954183
# Iteration 165, loss = 1.46605263
# Iteration 166, loss = 1.46700014
# Iteration 167, loss = 1.46493248
# Iteration 168, loss = 1.46560037
# Iteration 169, loss = 1.46395863
# Iteration 170, loss = 1.46202776
# Iteration 171, loss = 1.46684957
# Iteration 172, loss = 1.46495992
# Iteration 173, loss = 1.45923352
# Iteration 174, loss = 1.45864967
# Iteration 175, loss = 1.45817924
# Iteration 176, loss = 1.46001895
# Iteration 177, loss = 1.46062089
# Iteration 178, loss = 1.45761267
# Iteration 179, loss = 1.45845014
# Iteration 180, loss = 1.45574947
# Iteration 181, loss = 1.45403909
# Iteration 182, loss = 1.45357589
# Iteration 183, loss = 1.45696376
# Iteration 184, loss = 1.46425796
# Iteration 185, loss = 1.46088845
# Iteration 186, loss = 1.45289783
# Iteration 187, loss = 1.44838919
# Iteration 188, loss = 1.44677804
# Iteration 189, loss = 1.45683681
# Iteration 190, loss = 1.44956261
# Iteration 191, loss = 1.44442099
# Iteration 192, loss = 1.44807352
# Iteration 193, loss = 1.44522096
# Iteration 194, loss = 1.44517644
# Iteration 195, loss = 1.44397641
# Iteration 196, loss = 1.44151456
# Iteration 197, loss = 1.44282492
# Iteration 198, loss = 1.44003038
# Iteration 199, loss = 1.44449411
# Iteration 200, loss = 1.44137187
# Iteration 201, loss = 1.44037174
# Iteration 202, loss = 1.44715026
# Iteration 203, loss = 1.43670640
# Iteration 204, loss = 1.43794234
# Iteration 205, loss = 1.43786665
# Iteration 206, loss = 1.43869480
# Iteration 207, loss = 1.43272570
# Iteration 208, loss = 1.43479158
# Iteration 209, loss = 1.43395022
# Iteration 210, loss = 1.43829817
# Iteration 211, loss = 1.43060773
# Iteration 212, loss = 1.43101163
# Iteration 213, loss = 1.43165841
# Iteration 214, loss = 1.43462137
# Iteration 215, loss = 1.43642920
# Iteration 216, loss = 1.43127001
# Iteration 217, loss = 1.42628403
# Iteration 218, loss = 1.42599148
# Iteration 219, loss = 1.42523622
# Iteration 220, loss = 1.42521915
# Iteration 221, loss = 1.42791337
# Iteration 222, loss = 1.42333727
# Iteration 223, loss = 1.42229392
# Iteration 224, loss = 1.42100911
# Iteration 225, loss = 1.42892036
# Iteration 226, loss = 1.42562827
# Iteration 227, loss = 1.42339381
# Iteration 228, loss = 1.42188801
# Iteration 229, loss = 1.41875202
# Iteration 230, loss = 1.41924173
# Iteration 231, loss = 1.41773759
# Iteration 232, loss = 1.41851287
# Iteration 233, loss = 1.41667006
# Iteration 234, loss = 1.41741851
# Iteration 235, loss = 1.41547923
# Iteration 236, loss = 1.42104838
# Iteration 237, loss = 1.42093691
# Iteration 238, loss = 1.41692123
# Iteration 239, loss = 1.41126658
# Iteration 240, loss = 1.41147659
# Iteration 241, loss = 1.41023270
# Iteration 242, loss = 1.41221211
# Iteration 243, loss = 1.41186203
# Iteration 244, loss = 1.41184684
# Iteration 245, loss = 1.41142592
# Iteration 246, loss = 1.41239875
# Iteration 247, loss = 1.40570439
# Iteration 248, loss = 1.40867499
# Iteration 249, loss = 1.41234831
# Iteration 250, loss = 1.41186527
# Iteration 251, loss = 1.40681454
# Iteration 252, loss = 1.40318132
# Iteration 253, loss = 1.40512516
# Iteration 254, loss = 1.40538010
# Iteration 255, loss = 1.40187309
# Iteration 256, loss = 1.39971654
# Iteration 257, loss = 1.40226964
# Iteration 258, loss = 1.40332317
# Iteration 259, loss = 1.39893509
# Iteration 260, loss = 1.39968435
# Iteration 261, loss = 1.39953170
# Iteration 262, loss = 1.39801578
# Iteration 263, loss = 1.40040550
# Iteration 264, loss = 1.40113682
# Iteration 265, loss = 1.40682343
# Iteration 266, loss = 1.39925003
# Iteration 267, loss = 1.39475752
# Iteration 268, loss = 1.40228644
# Iteration 269, loss = 1.39824666
# Iteration 270, loss = 1.39446062
# Iteration 271, loss = 1.39177211
# Iteration 272, loss = 1.39538399
# Iteration 273, loss = 1.39415123
# Iteration 274, loss = 1.39043314
# Iteration 275, loss = 1.39009398
# Iteration 276, loss = 1.38971670
# Iteration 277, loss = 1.38878384
# Iteration 278, loss = 1.38885066
# Iteration 279, loss = 1.39215490
# Iteration 280, loss = 1.39964188
# Iteration 281, loss = 1.38808508
# Iteration 282, loss = 1.38923427
# Iteration 283, loss = 1.38626552
# Iteration 284, loss = 1.38557542
# Iteration 285, loss = 1.39027237
# Iteration 286, loss = 1.38885181
# Iteration 287, loss = 1.39101224
# Iteration 288, loss = 1.38432362
# Iteration 289, loss = 1.38305539
# Iteration 290, loss = 1.38644474
# Iteration 291, loss = 1.38554219
# Iteration 292, loss = 1.38899979
# Iteration 293, loss = 1.38272685
# Iteration 294, loss = 1.39816949
# Iteration 295, loss = 1.38991820
# Iteration 296, loss = 1.38709498
# Iteration 297, loss = 1.37983726
# Iteration 298, loss = 1.38130391
# Iteration 299, loss = 1.37917889
# Iteration 300, loss = 1.37554594
# Iteration 301, loss = 1.38395636
# Iteration 302, loss = 1.37568261
# Iteration 303, loss = 1.37400226
# Iteration 304, loss = 1.37421054
# Iteration 305, loss = 1.37234969
# Iteration 306, loss = 1.37505314
# Iteration 307, loss = 1.37311174
# Iteration 308, loss = 1.37321513
# Iteration 309, loss = 1.37241895
# Iteration 310, loss = 1.37109625
# Iteration 311, loss = 1.36983950
# Iteration 312, loss = 1.37641732
# Iteration 313, loss = 1.37440753
# Iteration 314, loss = 1.37225008
# Iteration 315, loss = 1.36969619
# Iteration 316, loss = 1.37308422
# Iteration 317, loss = 1.37006666
# Iteration 318, loss = 1.36927204
# Iteration 319, loss = 1.37211747
# Iteration 320, loss = 1.36611170
# Iteration 321, loss = 1.36786122
# Iteration 322, loss = 1.36365352
# Iteration 323, loss = 1.36669683
# Iteration 324, loss = 1.36672711
# Iteration 325, loss = 1.36463348
# Iteration 326, loss = 1.36922989
# Iteration 327, loss = 1.36225782
# Iteration 328, loss = 1.36555956
# Iteration 329, loss = 1.36474049
# Iteration 330, loss = 1.37341520
# Iteration 331, loss = 1.36139312
# Iteration 332, loss = 1.36425718
# Iteration 333, loss = 1.36188605
# Iteration 334, loss = 1.36364912
# Iteration 335, loss = 1.36333685
# Iteration 336, loss = 1.35685056
# Iteration 337, loss = 1.35794695
# Iteration 338, loss = 1.35523158
# Iteration 339, loss = 1.36306146
# Iteration 340, loss = 1.35896516
# Iteration 341, loss = 1.36378987
# Iteration 342, loss = 1.35466219
# Iteration 343, loss = 1.35448848
# Iteration 344, loss = 1.35450600
# Iteration 345, loss = 1.35493304
# Iteration 346, loss = 1.35987581
# Iteration 347, loss = 1.35623733
# Iteration 348, loss = 1.36480121
# Iteration 349, loss = 1.36041665
# Iteration 350, loss = 1.35857727
# Iteration 351, loss = 1.35517238
# Iteration 352, loss = 1.35114958
# Iteration 353, loss = 1.35111781
# Iteration 354, loss = 1.35065762
# Iteration 355, loss = 1.35151992
# Iteration 356, loss = 1.34823542
# Iteration 357, loss = 1.34808630
# Iteration 358, loss = 1.35370856
# Iteration 359, loss = 1.34615877
# Iteration 360, loss = 1.35028866
# Iteration 361, loss = 1.34633842
# Iteration 362, loss = 1.34425211
# Iteration 363, loss = 1.34533468
# Iteration 364, loss = 1.34401129
# Iteration 365, loss = 1.34389141
# Iteration 366, loss = 1.34415945
# Iteration 367, loss = 1.34152760
# Iteration 368, loss = 1.34511987
# Iteration 369, loss = 1.34232252
# Iteration 370, loss = 1.34058889
# Iteration 371, loss = 1.34306888
# Iteration 372, loss = 1.34307899
# Iteration 373, loss = 1.34038378
# Iteration 374, loss = 1.34705073
# Iteration 375, loss = 1.33919222
# Iteration 376, loss = 1.34134986
# Iteration 377, loss = 1.33963642
# Iteration 378, loss = 1.34141147
# Iteration 379, loss = 1.34539629
# Iteration 380, loss = 1.33533264
# Iteration 381, loss = 1.33993508
# Iteration 382, loss = 1.33965759
# Iteration 383, loss = 1.34124188
# Iteration 384, loss = 1.33856855
# Iteration 385, loss = 1.33534128
# Iteration 386, loss = 1.33763569
# Iteration 387, loss = 1.33391070
# Iteration 388, loss = 1.33640494
# Iteration 389, loss = 1.33897267
# Iteration 390, loss = 1.33097397
# Iteration 391, loss = 1.33024378
# Iteration 392, loss = 1.33102810
# Iteration 393, loss = 1.33185802
# Iteration 394, loss = 1.33242380
# Iteration 395, loss = 1.33224840
# Iteration 396, loss = 1.33776199
# Iteration 397, loss = 1.33100593
# Iteration 398, loss = 1.32865732
# Iteration 399, loss = 1.33011352
# Iteration 400, loss = 1.32870018
# Iteration 401, loss = 1.32865754
# Iteration 402, loss = 1.33034727
# Iteration 403, loss = 1.32784660
# Iteration 404, loss = 1.32572526
# Iteration 405, loss = 1.32730920
# Iteration 406, loss = 1.32464391
# Iteration 407, loss = 1.32571975
# Iteration 408, loss = 1.32494697
# Iteration 409, loss = 1.32399202
# Iteration 410, loss = 1.32351857
# Iteration 411, loss = 1.32233529
# Iteration 412, loss = 1.32761747
# Iteration 413, loss = 1.32433892
# Iteration 414, loss = 1.32493934
# Iteration 415, loss = 1.32206652
# Iteration 416, loss = 1.31968542
# Iteration 417, loss = 1.32402021
# Iteration 418, loss = 1.32040757
# Iteration 419, loss = 1.31943672
# Iteration 420, loss = 1.32091549
# Iteration 421, loss = 1.31926750
# Iteration 422, loss = 1.31872359
# Iteration 423, loss = 1.33125280
# Iteration 424, loss = 1.32521376
# Iteration 425, loss = 1.31595682
# Iteration 426, loss = 1.31691817
# Iteration 427, loss = 1.31876387
# Iteration 428, loss = 1.31733758
# Iteration 429, loss = 1.31679451
# Iteration 430, loss = 1.31940309
# Iteration 431, loss = 1.31765460
# Iteration 432, loss = 1.31689952
# Iteration 433, loss = 1.31325380
# Iteration 434, loss = 1.31201255
# Iteration 435, loss = 1.31228442
# Iteration 436, loss = 1.31545373
# Iteration 437, loss = 1.31126004
# Iteration 438, loss = 1.31097616
# Iteration 439, loss = 1.31390088
# Iteration 440, loss = 1.32110879
# Iteration 441, loss = 1.31636257
# Iteration 442, loss = 1.31353399
# Iteration 443, loss = 1.32235851
# Iteration 444, loss = 1.31467056
# Iteration 445, loss = 1.31091686
# Iteration 446, loss = 1.30724908
# Iteration 447, loss = 1.31032062
# Iteration 448, loss = 1.30768256
# Iteration 449, loss = 1.31036750
# Iteration 450, loss = 1.30649805
# Iteration 451, loss = 1.30897882
# Iteration 452, loss = 1.31662909
# Iteration 453, loss = 1.31622010
# Iteration 454, loss = 1.31559063
# Iteration 455, loss = 1.31707480
# Iteration 456, loss = 1.31554625
# Iteration 457, loss = 1.31367160
# Iteration 458, loss = 1.30324141
# Iteration 459, loss = 1.30778902
# Iteration 460, loss = 1.30213454
# Iteration 461, loss = 1.30352469
# Iteration 462, loss = 1.30195542
# Iteration 463, loss = 1.30553578
# Iteration 464, loss = 1.29930237
# Iteration 465, loss = 1.30085288
# Iteration 466, loss = 1.29772142
# Iteration 467, loss = 1.29838422
# Iteration 468, loss = 1.30018829
# Iteration 469, loss = 1.30161030
# Iteration 470, loss = 1.30226100
# Iteration 471, loss = 1.29741300
# Iteration 472, loss = 1.29735555
# Iteration 473, loss = 1.29581752
# Iteration 474, loss = 1.29721443
# Iteration 475, loss = 1.30081651
# Iteration 476, loss = 1.29798575
# Iteration 477, loss = 1.29389528
# Iteration 478, loss = 1.29714535
# Iteration 479, loss = 1.30050680
# Iteration 480, loss = 1.29802185
# Iteration 481, loss = 1.29280480
# Iteration 482, loss = 1.30369742
# Iteration 483, loss = 1.28997259
# Iteration 484, loss = 1.29305920
# Iteration 485, loss = 1.29161507
# Iteration 486, loss = 1.29709094
# Iteration 487, loss = 1.28982132
# Iteration 488, loss = 1.29115705
# Iteration 489, loss = 1.28937239
# Iteration 490, loss = 1.28933020
# Iteration 491, loss = 1.28774615
# Iteration 492, loss = 1.29726343
# Iteration 493, loss = 1.29591711
# Iteration 494, loss = 1.29111462
# Iteration 495, loss = 1.28825112
# Iteration 496, loss = 1.28600632
# Iteration 497, loss = 1.29104720
# Iteration 498, loss = 1.28635392
# Iteration 499, loss = 1.28901583
# Iteration 500, loss = 1.28934480
# Iteration 501, loss = 1.28298203
# Iteration 502, loss = 1.28516891
# Iteration 503, loss = 1.28477086
# Iteration 504, loss = 1.28544647
# Iteration 505, loss = 1.28233559
# Iteration 506, loss = 1.29594297
# Iteration 507, loss = 1.29092557
# Iteration 508, loss = 1.28377049
# Iteration 509, loss = 1.28582586
# Iteration 510, loss = 1.28302582
# Iteration 511, loss = 1.28042932
# Iteration 512, loss = 1.27997870
# Iteration 513, loss = 1.28138399
# Iteration 514, loss = 1.28448618
# Iteration 515, loss = 1.28345272
# Iteration 516, loss = 1.28722795
# Iteration 517, loss = 1.27696561
# Iteration 518, loss = 1.27770996
# Iteration 519, loss = 1.27729061
# Iteration 520, loss = 1.28012129
# Iteration 521, loss = 1.28545827
# Iteration 522, loss = 1.27692921
# Iteration 523, loss = 1.28470097
# Iteration 524, loss = 1.28387768
# Iteration 525, loss = 1.28020983
# Iteration 526, loss = 1.27991986
# Iteration 527, loss = 1.27141037
# Iteration 528, loss = 1.27803070
# Iteration 529, loss = 1.27474799
# Iteration 530, loss = 1.27513157
# Iteration 531, loss = 1.27344956
# Iteration 532, loss = 1.27131760
# Iteration 533, loss = 1.27230596
# Iteration 534, loss = 1.27375111
# Iteration 535, loss = 1.27114643
# Iteration 536, loss = 1.27980847
# Iteration 537, loss = 1.28108964
# Iteration 538, loss = 1.27585013
# Iteration 539, loss = 1.27369797
# Iteration 540, loss = 1.27030100
# Iteration 541, loss = 1.27040207
# Iteration 542, loss = 1.26924233
# Iteration 543, loss = 1.27029415
# Iteration 544, loss = 1.26693088
# Iteration 545, loss = 1.26851685
# Iteration 546, loss = 1.26991898
# Iteration 547, loss = 1.26774809
# Iteration 548, loss = 1.26807467
# Iteration 549, loss = 1.27162855
# Iteration 550, loss = 1.26736886
# Iteration 551, loss = 1.26553121
# Iteration 552, loss = 1.27444117
# Iteration 553, loss = 1.27263488
# Iteration 554, loss = 1.26635539
# Iteration 555, loss = 1.26930856
# Iteration 556, loss = 1.27479773
# Iteration 557, loss = 1.26803831
# Iteration 558, loss = 1.26581723
# Iteration 559, loss = 1.26477935
# Iteration 560, loss = 1.27088864
# Iteration 561, loss = 1.26199801
# Iteration 562, loss = 1.26213837
# Iteration 563, loss = 1.26179844
# Iteration 564, loss = 1.25941093
# Iteration 565, loss = 1.26153050
# Iteration 566, loss = 1.25916818
# Iteration 567, loss = 1.26289424
# Iteration 568, loss = 1.26365458
# Iteration 569, loss = 1.25827403
# Iteration 570, loss = 1.25909302
# Iteration 571, loss = 1.25857879
# Iteration 572, loss = 1.26580089
# Iteration 573, loss = 1.25802827
# Iteration 574, loss = 1.26234331
# Iteration 575, loss = 1.26522994
# Iteration 576, loss = 1.25569101
# Iteration 577, loss = 1.25557416
# Iteration 578, loss = 1.25624273
# Iteration 579, loss = 1.25883183
# Iteration 580, loss = 1.26758730
# Iteration 581, loss = 1.26661417
# Iteration 582, loss = 1.25413491
# Iteration 583, loss = 1.26278027
# Iteration 584, loss = 1.25860074
# Iteration 585, loss = 1.25512841
# Iteration 586, loss = 1.25457264
# Iteration 587, loss = 1.25301083
# Iteration 588, loss = 1.25290300
# Iteration 589, loss = 1.25414254
# Iteration 590, loss = 1.25294801
# Iteration 591, loss = 1.24911296
# Iteration 592, loss = 1.25256578
# Iteration 593, loss = 1.25229968
# Iteration 594, loss = 1.24969265
# Iteration 595, loss = 1.24845590
# Iteration 596, loss = 1.25762612
# Iteration 597, loss = 1.25648414
# Iteration 598, loss = 1.26107247
# Iteration 599, loss = 1.24721651
# Iteration 600, loss = 1.24653345
# Iteration 601, loss = 1.24679641
# Iteration 602, loss = 1.24937296
# Iteration 603, loss = 1.25041268
# Iteration 604, loss = 1.25547560
# Iteration 605, loss = 1.24443437
# Iteration 606, loss = 1.24697778
# Iteration 607, loss = 1.24961024
# Iteration 608, loss = 1.24431454
# Iteration 609, loss = 1.24377714
# Iteration 610, loss = 1.24428849
# Iteration 611, loss = 1.24181911
# Iteration 612, loss = 1.24667336
# Iteration 613, loss = 1.25022009
# Iteration 614, loss = 1.24667216
# Iteration 615, loss = 1.24492379
# Iteration 616, loss = 1.24151229
# Iteration 617, loss = 1.24259916
# Iteration 618, loss = 1.24490211
# Iteration 619, loss = 1.24789042
# Iteration 620, loss = 1.24024496
# Iteration 621, loss = 1.23930155
# Iteration 622, loss = 1.24059564
# Iteration 623, loss = 1.23962707
# Iteration 624, loss = 1.23712225
# Iteration 625, loss = 1.23624650
# Iteration 626, loss = 1.24461679
# Iteration 627, loss = 1.24788052
# Iteration 628, loss = 1.24281187
# Iteration 629, loss = 1.24208361
# Iteration 630, loss = 1.23879828
# Iteration 631, loss = 1.23865278
# Iteration 632, loss = 1.23632626
# Iteration 633, loss = 1.23813218
# Iteration 634, loss = 1.23897236
# Iteration 635, loss = 1.23531110
# Iteration 636, loss = 1.23893642
# Iteration 637, loss = 1.23465086
# Iteration 638, loss = 1.23546997
# Iteration 639, loss = 1.23432069
# Iteration 640, loss = 1.23255130
# Iteration 641, loss = 1.23612988
# Iteration 642, loss = 1.23392376
# Iteration 643, loss = 1.23447934
# Iteration 644, loss = 1.23352361
# Iteration 645, loss = 1.23061835
# Iteration 646, loss = 1.23060766
# Iteration 647, loss = 1.23027063
# Iteration 648, loss = 1.23191835
# Iteration 649, loss = 1.23354789
# Iteration 650, loss = 1.22939341
# Iteration 651, loss = 1.23345407
# Iteration 652, loss = 1.23540526
# Iteration 653, loss = 1.23675931
# Iteration 654, loss = 1.23485244
# Iteration 655, loss = 1.24188503
# Iteration 656, loss = 1.24403090
# Iteration 657, loss = 1.22956013
# Iteration 658, loss = 1.23166895
# Iteration 659, loss = 1.22748840
# Iteration 660, loss = 1.22763729
# Iteration 661, loss = 1.22569926
# Iteration 662, loss = 1.22581192
# Iteration 663, loss = 1.22608950
# Iteration 664, loss = 1.22764284
# Iteration 665, loss = 1.22368038
# Iteration 666, loss = 1.22261529
# Iteration 667, loss = 1.22388115
# Iteration 668, loss = 1.22306193
# Iteration 669, loss = 1.22624000
# Iteration 670, loss = 1.22478115
# Iteration 671, loss = 1.22474297
# Iteration 672, loss = 1.23012186
# Iteration 673, loss = 1.22759572
# Iteration 674, loss = 1.22267939
# Iteration 675, loss = 1.22241604
# Iteration 676, loss = 1.22324898
# Iteration 677, loss = 1.22234809
# Iteration 678, loss = 1.21899756
# Iteration 679, loss = 1.21910409
# Iteration 680, loss = 1.21844709
# Iteration 681, loss = 1.21729134
# Iteration 682, loss = 1.21992259
# Iteration 683, loss = 1.21946981
# Iteration 684, loss = 1.22903298
# Iteration 685, loss = 1.21759323
# Iteration 686, loss = 1.22388175
# Iteration 687, loss = 1.21523557
# Iteration 688, loss = 1.21511152
# Iteration 689, loss = 1.22009992
# Iteration 690, loss = 1.21888746
# Iteration 691, loss = 1.22707977
# Iteration 692, loss = 1.22319625
# Iteration 693, loss = 1.21565081
# Iteration 694, loss = 1.21663660
# Iteration 695, loss = 1.21832183
# Iteration 696, loss = 1.22942224
# Iteration 697, loss = 1.22452675
# Iteration 698, loss = 1.21422348
# Iteration 699, loss = 1.21407639
# Iteration 700, loss = 1.22422384
# Iteration 701, loss = 1.21415151
# Iteration 702, loss = 1.21541741
# Iteration 703, loss = 1.21469791
# Iteration 704, loss = 1.20978228
# Iteration 705, loss = 1.21609062
# Iteration 706, loss = 1.21313355
# Iteration 707, loss = 1.21062516
# Iteration 708, loss = 1.21069201
# Iteration 709, loss = 1.20735562
# Iteration 710, loss = 1.21328653
# Iteration 711, loss = 1.20895650
# Iteration 712, loss = 1.20994647
# Iteration 713, loss = 1.20966180
# Iteration 714, loss = 1.21121843
# Iteration 715, loss = 1.21087221
# Iteration 716, loss = 1.20852106
# Iteration 717, loss = 1.20845027
# Iteration 718, loss = 1.20836595
# Iteration 719, loss = 1.20789963
# Iteration 720, loss = 1.20804797
# Training loss did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.

# %%
with open('test_predictions_avg_rating.txt','a') as f:
    for el in predictions_test_round:
        f.write(str(el)+"\n")

# %%
len(open('test_predictions_avg_rating.txt','r').readlines())
# Out:
# 1582

# %% [markdown]
# # test predictions

# %%
traindf.to_json(traindf_path)
testdf.to_json(testdf_file_path)

# %% [markdown]
# # XGB training

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
# y_train = le.fit_transform(y_train)

X = traindf_standard_all[['Hinglish_cmi_scores_standardized',
       'Hinglish_burstiness_scores_standardized',
       'Hinglish_sp_scores_standardized',
        'symcom_scores_sent_standardized',
       'NOUN_symcom_standardized', 'AUX_symcom_standardized',
       'CCONJ_symcom_standardized', 'ADP_symcom_standardized',
       'NUM_symcom_standardized', 'PRON_symcom_standardized',
       'PART_symcom_standardized', 'VERB_symcom_standardized',
       'PROPN_symcom_standardized', 'SCONJ_symcom_standardized',
       'ADV_symcom_standardized', 'INTJ_symcom_standardized',
       'DET_symcom_standardized', 'ADJ_symcom_standardized',
       'symcom_+1_count_standardized', 'symcom_-1_count_standardized',
       'symcom_na_count_standardized', 'symcom_others_standardized',
       'xlm_r_ppl_scores_delta_standardized', 'Hinglish_length_standardized',
         'eucl_standardized', 'cityblock_standardized', 'cosine_standardized']]


sim = SimpleImputer(missing_values=np.nan, strategy='mean')

X_imputed_data = sim.fit_transform(X.values)

y = traindf_standard_all["Average rating"]
y = le.fit_transform(y)

# regr = MLPRegressor(random_state=1, max_iter=10000, verbose = True).fit(X_imputed_data, y)
model = XGBClassifier(use_label_encoder=False, eval_metric='mlogloss')
model.fit(X_imputed_data, y)

X_test = testdf_standard_all[['Hinglish_cmi_scores_standardized',
       'Hinglish_burstiness_scores_standardized',
       'Hinglish_sp_scores_standardized',
        'symcom_scores_sent_standardized',
       'NOUN_symcom_standardized', 'AUX_symcom_standardized',
       'CCONJ_symcom_standardized', 'ADP_symcom_standardized',
       'NUM_symcom_standardized', 'PRON_symcom_standardized',
       'PART_symcom_standardized', 'VERB_symcom_standardized',
       'PROPN_symcom_standardized', 'SCONJ_symcom_standardized',
       'ADV_symcom_standardized', 'INTJ_symcom_standardized',
       'DET_symcom_standardized', 'ADJ_symcom_standardized',
       'symcom_+1_count_standardized', 'symcom_-1_count_standardized',
       'symcom_na_count_standardized', 'symcom_others_standardized',
        'xlm_r_ppl_scores_delta_standardized', 'Hinglish_length_standardized',
         'eucl_standardized', 'cityblock_standardized', 'cosine_standardized']]

X_test_imputed = sim.transform(X_test)

predictions_test = model.predict(X_test_imputed)
predictions_test = le.inverse_transform(predictions_test)

predictions_test_round = [round(el) for el in predictions_test]

# %%
with open('test_predictions_avg_rating.txt','w') as f:
    for el in predictions_test_round:
        f.write(str(el)+"\n")

# %%
le = LabelEncoder()

X = traindf_standard_all[['Hinglish_cmi_scores_standardized',
       'Hinglish_burstiness_scores_standardized',
       'Hinglish_sp_scores_standardized',
        'symcom_scores_sent_standardized',
       'NOUN_symcom_standardized', 'AUX_symcom_standardized',
       'CCONJ_symcom_standardized', 'ADP_symcom_standardized',
       'NUM_symcom_standardized', 'PRON_symcom_standardized',
       'PART_symcom_standardized', 'VERB_symcom_standardized',
       'PROPN_symcom_standardized', 'SCONJ_symcom_standardized',
       'ADV_symcom_standardized', 'INTJ_symcom_standardized',
       'DET_symcom_standardized', 'ADJ_symcom_standardized',
       'symcom_+1_count_standardized', 'symcom_-1_count_standardized',
       'symcom_na_count_standardized', 'symcom_others_standardized',
        'xlm_r_ppl_scores_delta_standardized', 'Hinglish_length_standardized',
                         'eucl_standardized', 'cityblock_standardized', 'cosine_standardized']]


sim = SimpleImputer(missing_values=np.nan, strategy='mean')

X_imputed_data = sim.fit_transform(X.values)

y = traindf_standard_all["Disagreement"]
y = le.fit_transform(y)

model = XGBClassifier(use_label_encoder=False, eval_metric='mlogloss')
model.fit(X_imputed_data, y)

X_test = testdf_standard_all[['Hinglish_cmi_scores_standardized',
       'Hinglish_burstiness_scores_standardized',
       'Hinglish_sp_scores_standardized',
        'symcom_scores_sent_standardized',
       'NOUN_symcom_standardized', 'AUX_symcom_standardized',
       'CCONJ_symcom_standardized', 'ADP_symcom_standardized',
       'NUM_symcom_standardized', 'PRON_symcom_standardized',
       'PART_symcom_standardized', 'VERB_symcom_standardized',
       'PROPN_symcom_standardized', 'SCONJ_symcom_standardized',
       'ADV_symcom_standardized', 'INTJ_symcom_standardized',
       'DET_symcom_standardized', 'ADJ_symcom_standardized',
       'symcom_+1_count_standardized', 'symcom_-1_count_standardized',
       'symcom_na_count_standardized', 'symcom_others_standardized',
        'xlm_r_ppl_scores_delta_standardized', 'Hinglish_length_standardized',
                            'eucl_standardized', 'cityblock_standardized', 'cosine_standardized']]

X_test_imputed = sim.transform(X_test)

predictions_test = model.predict(X_test_imputed)
predictions_test = le.inverse_transform(predictions_test)

predictions_test_round = [round(el) for el in predictions_test]

# %%
with open('test_predictions_disagreement.txt','w') as f:
    for el in predictions_test_round:
        f.write(str(el)+"\n")
